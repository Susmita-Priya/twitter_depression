# %% [markdown]
# <a href="https://colab.research.google.com/github/Susmita-Priya/twitter_depression/blob/main/Twitter_dataset1(preprocessing).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Depression Detection Using Twitter Dataset

# %%
#IMPORTING NECESSARY LIBRARIES

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
np.random.seed(42)
tf.random.set_seed(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
twitter_df = pd.read_csv('/content/drive/MyDrive/Dataset/sentiment_tweets3.csv', encoding =('ISO-8859-1'),low_memory =False)
twitter_df
# Out:
#         Index                                 message to examine  \
# 0         106  just had a real good moment. i missssssssss hi...
# 1         217         is reading manga  http://plurk.com/p/mzp1e
# 2         220  @comeagainjen http://twitpic.com/2y2lx - http:...
# 3         288  @lapcat Need to send 'em to my accountant tomo...
# 4         540      ADD ME ON MYSPACE!!!  myspace.com/LookThunder
# ...       ...                                                ...
# 10309  802309  No Depression by G Herbo is my mood from now o...
# 10310  802310  What do you do when depression succumbs the br...
# 10311  802311  Ketamine Nasal Spray Shows Promise Against Dep...
# 10312  802312  dont mistake a bad day with depression! everyo...
# 10313  802313                                                  0
#
#        label (depression result)
# 0                              0
# 1                              0
# 2                              0
# 3                              0
# 4                              0
# ...                          ...
# 10309                          1
# 10310                          1
# 10311                          1
# 10312                          1
# 10313                          1
#
# [10314 rows x 3 columns]

# %%
# RENAMING COLUMNS

twitter_df = twitter_df.rename(columns = {"message to examine":"Text", "label (depression result)" :"Category" })

# %%
# REVIEW DATA AFTER CHANGES

twitter_df.head(5)
# Out:
#    Index                                               Text  Category
# 0    106  just had a real good moment. i missssssssss hi...         0
# 1    217         is reading manga  http://plurk.com/p/mzp1e         0
# 2    220  @comeagainjen http://twitpic.com/2y2lx - http:...         0
# 3    288  @lapcat Need to send 'em to my accountant tomo...         0
# 4    540      ADD ME ON MYSPACE!!!  myspace.com/LookThunder         0

# %%
# KEEPING ONLY THE 2 NECESSARY COLUMNS

twitter_df = twitter_df[["Text", "Category"]]

# %%
# REVIEW DATA AFTER CHANGES

twitter_df.head(5)
# Out:
#                                                 Text  Category
# 0  just had a real good moment. i missssssssss hi...         0
# 1         is reading manga  http://plurk.com/p/mzp1e         0
# 2  @comeagainjen http://twitpic.com/2y2lx - http:...         0
# 3  @lapcat Need to send 'em to my accountant tomo...         0
# 4      ADD ME ON MYSPACE!!!  myspace.com/LookThunder         0

# %%
## Let's see some of the text

twitter_df.loc[10311]['Text']
# Out:
# 'Ketamine Nasal Spray Shows Promise Against Depression, Suicide #health https://cmun.it/4sjligkÃ\x82Â\xa0'

# %%
# CHECK THE SHAPE OF THE DATA

twitter_df.shape
# Out:
# (10314, 2)

# %%
# CHECK INFO REGARDING IT

twitter_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10314 entries, 0 to 10313
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Text      10314 non-null  object
#  1   Category  10314 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 161.3+ KB

# %%
twitter_df["Category"].value_counts()
# Out:
# 0    8000
# 1    2314
# Name: Category, dtype: int64

# %%
# CHECKING COUNTS OF CATEGORIES

fig = plt.figure(figsize =(7, 7))
plt.bar(twitter_df["Category"].unique(), twitter_df["Category"].value_counts(),
         color =['red', 'green'])
plt.title("COUNTS OF CATEGORIES OF BEING DEPRESSED OR NOT")
# Out:
# Text(0.5, 1.0, 'COUNTS OF CATEGORIES OF BEING DEPRESSED OR NOT')

# %%
# install wordcloud

# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.10/dist-packages (from wordcloud) (1.23.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from wordcloud) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
# CREATING WORDCLOUD TO CHECK MOST OCCURING WORDS IN PREPROCESSED DATA

from wordcloud import WordCloud, STOPWORDS
text = twitter_df['Text'].values

wordcloud = WordCloud().generate(str(text))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.figure(figsize = (40,40), facecolor = None)

# %% [markdown]
# # **Preprocessing**

# %%
# TEXTACY is used for text preprocessing
# !pip install textacy
# Out:
# Collecting textacy
#   Downloading textacy-0.13.0-py3-none-any.whl (210 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 210.7/210.7 kB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: cachetools>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (5.3.2)
# Requirement already satisfied: catalogue~=2.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (2.0.10)
# Collecting cytoolz>=0.10.1 (from textacy)
#   Downloading cytoolz-0.12.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 29.0 MB/s eta 0:00:00
# Collecting floret~=0.10.0 (from textacy)
#   Downloading floret-0.10.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (320 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 320.4/320.4 kB 18.6 MB/s eta 0:00:00
# Collecting jellyfish>=0.8.0 (from textacy)
#   Downloading jellyfish-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 56.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.3.2)
# Requirement already satisfied: networkx>=2.7 in /usr/local/lib/python3.10/dist-packages (from textacy) (3.2.1)
# Requirement already satisfied: numpy>=1.17.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.23.5)
# Collecting pyphen>=0.10.0 (from textacy)
#   Downloading pyphen-0.14.0-py3-none-any.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 66.8 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (2.31.0)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (1.2.2)
# Requirement already satisfied: spacy~=3.0 in /usr/local/lib/python3.10/dist-packages (from textacy) (3.6.1)
# Requirement already satisfied: tqdm>=4.19.6 in /usr/local/lib/python3.10/dist-packages (from textacy) (4.66.1)
# Requirement already satisfied: toolz>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from cytoolz>=0.10.1->textacy) (0.12.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.10.0->textacy) (2023.11.17)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0->textacy) (3.2.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (2.4.8)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (0.10.3)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (6.4.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy~=3.0->textacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy~=3.0->textacy) (4.5.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy~=3.0->textacy) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy~=3.0->textacy) (0.1.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy~=3.0->textacy) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy~=3.0->textacy) (2.1.3)
# Installing collected packages: pyphen, jellyfish, floret, cytoolz, textacy
# Successfully installed cytoolz-0.12.2 floret-0.10.5 jellyfish-1.0.3 pyphen-0.14.0 textacy-0.13.0

# %%
# IMPORT OTHER TEXT PREPROCESSING LIBRARIES

import nltk
nltk.download('omw-1.4')
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import re
from textacy import preprocessing
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
from nltk.corpus import wordnet
# Out:
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.

# %%
# CHECK IF THERE ARE NULL VALUES
twitter_df.isnull().sum()
# Out:
# Text        0
# Category    0
# dtype: int64

# %%
#check duplication
twitter_df.duplicated().sum()
# Out:
# 31

# %%
# REMOVING DUPLICATE VALUES
twitter_df = twitter_df.drop_duplicates()

# %%
# SHUFFLING OUR DATASET SINCE IT IS IS UNSHUFFLED AND FIRST 8000 ROWS BELONGED TO A CERTAIN CATEGORY
# Mixing depressed and non depressed text because previosly first 8000 is non depressed text and rest of the data is depressive

twitter_df = twitter_df.sample(frac=1)
twitter_df.head(5)
# Out:
#                                                    Text  Category
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1

# %%
# Check if there's any number

for i in twitter_df['Text']:
  for j in i.split():
    if j.isdigit():
      s = "yes"
    else:
      s = "no"
print(s)
# Out:
# no

# %%
# First Remove all the numbers

def remove_numbers(text):
  return ' '.join([i for i in str(text).split() if not i.isdigit()])

twitter_df['removed_numbers'] = twitter_df['Text'].apply(lambda x: remove_numbers(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...

# %%
# CONVERTING TEXT TO LOWER CASE

twitter_df["lowercase"] = twitter_df["removed_numbers"].str.lower()
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...

# %%
# Removal of Weblinks

def remove_weblinks(text):
  return re.sub(r"http\S+", "", text)

twitter_df['remove_weblink'] = twitter_df['lowercase'].apply(lambda x: remove_weblinks(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...

# %%
# Removal of URL

def remove_weblinks(text):
   text=re.sub(r"((https:|http|ftp)?(:\/\/)?(www\.)?)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&\/\/=]*)",' ',text)
   return re.sub(r'/', ' / ', text)
twitter_df['removed_url'] = twitter_df['remove_weblink'].apply(lambda x: remove_weblinks(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...

# %%
# Remove Twitter mention

def remove_twitter(text):
  return re.sub('@[\w]+','',text)
twitter_df['removed_mention'] = twitter_df['removed_url'].apply(lambda x: remove_twitter(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...

# %%
# REMOVING PUNCTUATION, EXTRA WHITESPACES AND HASHTAGS

preprocess = preprocessing.make_pipeline(
    preprocessing.remove.punctuation,
    preprocessing.normalize.whitespace,
    preprocessing.replace.hashtags,
)

twitter_df["remove_punctuation"] = twitter_df["removed_mention"].apply(preprocess)
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...

# %%
# REMOVING THE STOPWORDS
# Stopwords do not carry any significant meaning, such as "the", "and", "is", etc. Removing stopwords is a common text preprocessing step in natural language processing tasks as they can reduce noise in the data and improve the quality of analysis.

stop = stopwords.words('english')

twitter_df["remove_stopword"] = twitter_df['remove_punctuation'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...

# %%
#remove repeating_char
def clean_repeating_char(text):
    return re.sub(r"(.)\1\1+", r"\1\1", text)
twitter_df['remove_repeatedword'] = twitter_df['remove_punctuation'].apply(lambda x: clean_repeating_char(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword  \
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...
#
#                                     remove_repeatedword
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...

# %%
def clean_emoji(text):
    data = re.sub(r'<3', '<heart>', text)
    data = re.sub(r"[8:=;]['`\-]?[)d]+", '<smile>', text)
    data = re.sub(r"[8:=;]['`\-]?\(+", '<sad>', text)
    data = re.sub(r"[8:=;]['`\-]?[\/|l*]", '<neutral>', text)
    data = re.sub(r"[8:=;]['`\-]?p+", '<laugh>', text)
    return text
twitter_df['remove_emoji'] = twitter_df['remove_repeatedword'].apply(lambda x: clean_emoji(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword  \
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...
#
#                                     remove_repeatedword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_emoji
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...

# %%
def remove_images(text):
    cleaned_tweet = re.sub(r"pic\.twitter\.com/\S+",'', text)
    cleaned_tweet = re.sub("\w+(\.png|\.jpg|\.gif|\.jpeg)", " ", text)
    return cleaned_tweet

twitter_df["remove_image"] = twitter_df["remove_emoji"].apply(remove_images)
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword  \
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...
#
#                                     remove_repeatedword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_emoji  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_image
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...

# %%
# STEMMING THE WORDS
#Stemming is the process of reducing words to their base or root form, which can be useful for reducing the dimensionality of the text data.

from nltk.stem.snowball import SnowballStemmer
stemmer = SnowballStemmer("english")
twitter_df['stemmed'] = twitter_df['remove_image'].apply(lambda x: stemmer.stem(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword  \
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...
#
#                                     remove_repeatedword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_emoji  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_image  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                                 stemmed
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...

# %%
from collections import Counter
cnt = Counter()

for text in twitter_df['stemmed'].values:
  for word in text.split():
    cnt[word] += 1

cnt.most_common(10)
# Out:
# [('i', 5269),
#  ('to', 3828),
#  ('the', 3780),
#  ('a', 3083),
#  ('and', 2780),
#  ('you', 2696),
#  ('it', 2123),
#  ('depression', 2042),
#  ('my', 1912),
#  ('of', 1833)]

# %%
n_rare_words = 10
RAREWORDS = set([w for (w, wc) in cnt.most_common()[:-n_rare_words-1:-1]])

# Let's see what are the Rarewords

RAREWORDS
# Out:
# {'8=',
#  'amercian',
#  'answ',
#  'cha',
#  'gaeul',
#  'gtr',
#  'ob',
#  'vm',
#  'walle',
#  'yijung'}

# %%
# Let's remove these

def remove_rareword(text):
  return " ".join([word for word in str(text).split() if word not in RAREWORDS])
twitter_df['remove_rareword'] = twitter_df['stemmed'].apply(lambda x: remove_rareword(x))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword  \
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...
#
#                                     remove_repeatedword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_emoji  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_image  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                                 stemmed  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_rareword
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...

# %%
lemmatizer = WordNetLemmatizer()

wordnet_map = {"n": wordnet.NOUN, "v": wordnet.VERB, "j": wordnet.ADJ, "r": wordnet.ADV}

def lemmatize_words(text):
    pos_tagged_text = nltk.pos_tag(text.split())
    return " ".join([lemmatizer.lemmatize(word, wordnet_map.get(pos[0], wordnet.VERB)) for word, pos in pos_tagged_text])

twitter_df["lemmatized"] = twitter_df['remove_rareword'].apply(lambda text: lemmatize_words(text))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword  \
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...
#
#                                     remove_repeatedword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_emoji  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_image  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                                 stemmed  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_rareword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                              lemmatized
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im go for real this time bbl thank again to...
# 8426          depression be literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just say excersise and eat...

# %%
short_words = {
"aint": "am not",
"arent": "are not",
"cant": "cannot",
"'cause": "because",
"couldve": "could have",
"couldnt": "could not",
"didnt": "did not",
"doesnt": "does not",
"dont": "do not",
"hadnt": "had not",
"hasnt": "has not",
"havent": "have not",
"im": "I am",
"em": "them",
"ive": "I have",
"isnt": "is not",
"lets": "let us",
"theyre": "they are",
"theyve": "they have",
"wasnt": "was not",
"well": "we will",
"were": "we are",
"werent": "were not",
"you're": "you are",
"you've": "you have"
}

# %%
def replace_short_words(text):
  for word in text.split():
    if word in short_words:
      text = text.replace(word, short_words[word])

  return text
twitter_df["replace_shortword"] = twitter_df['lemmatized'].apply(lambda text: replace_short_words(text))
twitter_df.head(5)
# Out:
#                                                    Text  Category  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...         0
# 3891  Ok Im gone for real this time bbl Thanks again...         0
# 8426          Depression is literally the biggest bitch         1
# 6662                      @Wereuntouchable Thank youu!          0
# 8133  a real psychologist just said excersise and ea...         1
#
#                                         removed_numbers  \
# 6064  @tommcfly well if you weren't Tom Fletcher or ...
# 3891  Ok Im gone for real this time bbl Thanks again...
# 8426          Depression is literally the biggest bitch
# 6662                       @Wereuntouchable Thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                               lowercase  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                          remove_weblink  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                             removed_url  \
# 6064  @tommcfly well if you weren't tom fletcher or ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                       @wereuntouchable thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                         removed_mention  \
# 6064   well if you weren't tom fletcher or tom mcfly...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                        thank youu!
# 8133  a real psychologist just said excersise and ea...
#
#                                      remove_punctuation  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_stopword  \
# 6064  well tom fletcher tom mcfly would like could a...
# 3891  ok im gone real time bbl thanks new old follow...
# 8426                 depression literally biggest bitch
# 6662                                         thank youu
# 8133  real psychologist said excersise eating habits...
#
#                                     remove_repeatedword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_emoji  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                            remove_image  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                                 stemmed  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                         remove_rareword  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im gone for real this time bbl thanks again...
# 8426          depression is literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just said excersise and ea...
#
#                                              lemmatized  \
# 6064  well if you weren t tom fletcher or tom mcfly ...
# 3891  ok im go for real this time bbl thank again to...
# 8426          depression be literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just say excersise and eat...
#
#                                       replace_shortword
# 6064  we will if you weren t tom fletcher or tom mcf...
# 3891  ok I am go for real this tI ame bbl thank agai...
# 8426          depression be literally the biggest bitch
# 6662                                         thank youu
# 8133  a real psychologist just say excersise and eat...

# %%
twitter_df = twitter_df[['replace_shortword','Category']]
twitter_df.head(5)
# Out:
#                                       replace_shortword  Category
# 6064  we will if you weren t tom fletcher or tom mcf...         0
# 3891  ok I am go for real this tI ame bbl thank agai...         0
# 8426          depression be literally the biggest bitch         1
# 6662                                         thank youu         0
# 8133  a real psychologist just say excersise and eat...         1

# %%
twitter_df.columns = ['Text','Category']
twitter_df.head(5)
# Out:
#                                                    Text  Category
# 6064  we will if you weren t tom fletcher or tom mcf...         0
# 3891  ok I am go for real this tI ame bbl thank agai...         0
# 8426          depression be literally the biggest bitch         1
# 6662                                         thank youu         0
# 8133  a real psychologist just say excersise and eat...         1

# %%
# CREATING WORDCLOUD TO SEE MOST OCCURING WORDS AFTER PREPROCESSING

TEXT_AFTER_PREPROCESS = twitter_df['Text'].values

wordcloud = WordCloud().generate(str(TEXT_AFTER_PREPROCESS))

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
plt.figure(figsize = (40,40), facecolor = None)

# %% [markdown]
# # Text Preprocessing : Part **II**
# TEXT VECTORIZATION

# %%
# Assuming 'text' is the feature and 'label' is the target variable
X =  twitter_df['Text']
y = twitter_df['Category']

# %%
# IMPORTING LIBRARY TO IMPLEMENT TF-IDF ALGORITHM
from sklearn.feature_extraction.text import TfidfVectorizer

# TF-IDF Vectorization
vectorizer = TfidfVectorizer()
X_tfidf = vectorizer.fit_transform(X)

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %%
from sklearn.decomposition import TruncatedSVD
# Apply TruncatedSVD for dimensionality reduction to 2D
svd = TruncatedSVD(n_components=2)
X_svd = svd.fit_transform(X_train)

# Create a DataFrame for visualization
df_svd = pd.DataFrame(data=X_svd, columns=['SVD1', 'SVD2'])
df_svd['label'] = y_train

# Drop rows with NaN values in 'label' column (in case there are still NaN values after train-test split)
df_svd = df_svd.dropna(subset=['label'])

# Visualize the data in 2D if there are valid values
if not df_svd['label'].empty:
    plt.figure(figsize=(10, 8))
    scatter = plt.scatter(df_svd['SVD1'], df_svd['SVD2'], c=df_svd['label'], cmap='viridis')
    plt.legend(*scatter.legend_elements(), title='Classes')
    plt.title('2D Visualization of TF-IDF Vectors using TruncatedSVD')
    plt.xlabel('SVD1')
    plt.ylabel('SVD2')
    plt.show()
else:
    print("No valid values in the 'label' column after dropping NaN.")

# %% [markdown]
# # FITTING OUR MACHINE LEARNING MODELS

# %% [markdown]
# 1) LOGISTIC REGRESSION MODEL

# %%
# IMPORTING LIBRARY TO IMPLEMENT LOGISTIC REGRESSION

from sklearn.linear_model import LogisticRegression

# %%
# Create a machine learning model (Logistic Regression in this example)
model = LogisticRegression(random_state=42)

# Train the model on the TF-IDF transformed training set
model.fit(X_train, y_train)

# Make predictions on the TF-IDF transformed test set
y_pred_lr = model.predict(X_test)

# Evaluate the model
accuracy_lr = accuracy_score(y_test, y_pred_lr)
print(f"Accuracy: {accuracy_lr}")
# Out:
# Accuracy: 0.9790957705396208

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Plot confusion matrix
cm = confusion_matrix(y_pred_lr, y_test, labels = [1,0])
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("Logistic Regression Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# 2) DECISION TREE CLASSIFIER

# %%
from sklearn.tree import DecisionTreeClassifier

# Decision Tree
model = DecisionTreeClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred_dt = model.predict(X_test)

# Evaluate the model
accuracy_dt = accuracy_score(y_test, y_pred_dt)
print(f'Decision Tree Accuracy: {accuracy_dt}')
# Out:
# Decision Tree Accuracy: 0.9965969859017987

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Confusion matrix
cm = confusion_matrix(y_pred_dt, y_test, labels = [1,0])
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# 3) RANDOM FORESTS CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier

# Random Forest
model = RandomForestClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred_rf = model.predict(X_test)

# Evaluate the model
accuracy_rf = accuracy_score(y_test, y_pred_rf)
print(f'Random Forest Accuracy: {accuracy_rf}')
# Out:
# Random Forest Accuracy: 0.9970831307729704

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Confusion matrix
cm = confusion_matrix(y_pred_rf, y_test, labels = [1,0])
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("Random Forest Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# 4) Gradient Boosting Model:

# %%
from sklearn.ensemble import GradientBoostingClassifier

# Gradient Boosting
model = GradientBoostingClassifier(random_state=42)
model.fit(X_train, y_train)
y_pred_gb = model.predict(X_test)

# Evaluate the model
accuracy_gb = accuracy_score(y_test, y_pred_gb)
print(f'Accuracy: {accuracy_gb}')
# Out:
# Accuracy: 0.9970831307729704

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Confusion matrix
cm = confusion_matrix(y_pred_gb, y_test, labels = [1,0])
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("Gradient Boosting Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# 5) Naive Bayes Models

# %%
from sklearn.naive_bayes import MultinomialNB

# Naive Bayes
model = MultinomialNB()
model.fit(X_train, y_train)
y_pred_nb = model.predict(X_test)

# Evaluate the model
accuracy_nb = accuracy_score(y_test, y_pred_nb)
print(f'Naive Bayes Accuracy: {accuracy_nb}')
# Out:
# Naive Bayes Accuracy: 0.8891589693728731

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Confusion matrix
cm = confusion_matrix(y_pred_nb, y_test, labels = [1,0])
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("Naive Bayes Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Tokenize and pad sequences
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X)
sequences = tokenizer.texts_to_sequences(X)
X_padded = pad_sequences(sequences)

# %% [markdown]
# 6) LSTM model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense

# LSTM
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=X_padded.shape[1]))
model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Assuming binary classification, adjust accordingly
y_binary = (y > 0).astype(int)

# Split the dataset
X_trainn, X_testt, y_trainn, y_testt = train_test_split(X_padded, y_binary, test_size=0.2, random_state=42)

model.fit(X_trainn, y_trainn, epochs=5, batch_size=64)

# Evaluate the model
y_pred = model.predict(X_testt)
y_pred_lstm = (y_pred > 0.5).astype(int)
accuracy_lstm = accuracy_score(y_testt, y_pred_lstm)
print(f'LSTM Accuracy: {accuracy_lstm}')
# Out:
# Epoch 1/5
# 129/129 [==============================] - 18s 115ms/step - loss: 0.3105 - accuracy: 0.8710
# Epoch 2/5
# 129/129 [==============================] - 15s 117ms/step - loss: 0.0193 - accuracy: 0.9956
# Epoch 3/5
# 129/129 [==============================] - 15s 116ms/step - loss: 0.0055 - accuracy: 0.9989
# Epoch 4/5
# 129/129 [==============================] - 15s 116ms/step - loss: 0.0058 - accuracy: 0.9991
# Epoch 5/5
# 129/129 [==============================] - 16s 127ms/step - loss: 0.0049 - accuracy: 0.9988
# 65/65 [==============================] - 1s 15ms/step
# LSTM Accuracy: 0.9980554205153136

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Confusion matrix
cm = confusion_matrix(y_testt, y_pred_lstm)
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("LSTM Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# 7) CNN model

# %%
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, Dense

# CNN
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=X_padded.shape[1]))
model.add(Conv1D(128, 5, activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_trainn, y_trainn, epochs=5, batch_size=64)

# Evaluate the model
y_pred = model.predict(X_testt)
y_pred_cnn = (y_pred > 0.5).astype(int)
accuracy_cnn = accuracy_score(y_testt, y_pred_cnn)
print(f'CNN Accuracy: {accuracy_cnn}')
# Out:
# Epoch 1/5
# 129/129 [==============================] - 5s 34ms/step - loss: 0.2800 - accuracy: 0.8935
# Epoch 2/5
# 129/129 [==============================] - 6s 48ms/step - loss: 0.0192 - accuracy: 0.9962
# Epoch 3/5
# 129/129 [==============================] - 4s 31ms/step - loss: 0.0097 - accuracy: 0.9973
# Epoch 4/5
# 129/129 [==============================] - 4s 32ms/step - loss: 0.0042 - accuracy: 0.9991
# Epoch 5/5
# 129/129 [==============================] - 6s 46ms/step - loss: 0.0025 - accuracy: 0.9996
# 65/65 [==============================] - 1s 7ms/step
# CNN Accuracy: 0.997569275644142

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_cnn)
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("CNN Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# 8) RNN model

# %%
from tensorflow.keras.layers import SimpleRNN

# RNN
model = Sequential()
model.add(Embedding(input_dim=len(tokenizer.word_index) + 1, output_dim=64, input_length=X_padded.shape[1]))
model.add(SimpleRNN(100))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

model.fit(X_trainn, y_trainn, epochs=5, batch_size=64)

# Evaluate the model
y_pred = model.predict(X_testt)
y_pred_rnn = (y_pred > 0.5).astype(int)
accuracy_rnn = accuracy_score(y_testt, y_pred_rnn)
print(f'RNN Accuracy: {accuracy_rnn}')
# Out:
# Epoch 1/5
# 129/129 [==============================] - 6s 34ms/step - loss: 0.4139 - accuracy: 0.8230
# Epoch 2/5
# 129/129 [==============================] - 5s 36ms/step - loss: 0.1440 - accuracy: 0.9482
# Epoch 3/5
# 129/129 [==============================] - 6s 49ms/step - loss: 0.0394 - accuracy: 0.9902
# Epoch 4/5
# 129/129 [==============================] - 4s 35ms/step - loss: 0.0116 - accuracy: 0.9973
# Epoch 5/5
# 129/129 [==============================] - 5s 38ms/step - loss: 0.0053 - accuracy: 0.9991
# 65/65 [==============================] - 1s 7ms/step
# RNN Accuracy: 0.997569275644142

# %%
x_axis_labels = ["Positive(1)","Negative(0)"]
y_axis_labels = ["Positive(1)","Negative(0)"]

# Confusion matrix
cm = confusion_matrix(y_test, y_pred_rnn)
sns.heatmap(cm, xticklabels = x_axis_labels, yticklabels = y_axis_labels, annot = True, fmt='g',annot_kws = {'size': 16})
plt.title("RNN Confusion Matrix")
plt.xlabel("Actual Class", fontsize = 20)
plt.ylabel("Predicted Class", fontsize = 20)
plt.show()

# %% [markdown]
# EVALUATING OUR MODELS

# %%
# IMPORTING LIBRARIES TO EVALAUTE MODELS

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import log_loss

# %%
# CHECKING THE ACCURACY SCORES OF MODELS

print("THE ACCURACY SCORES OF OUR MODELS ARE AS FOLLOWS:", "\n")
print("Accuracy Score of our Logistic Regression Classifier is: ", accuracy_lr, "\n")
print("Accuracy Score of our Decision Tree Classifier is: ", accuracy_dt, "\n")
print("Accuracy Score of our Random Forest Classifier is: ", accuracy_rf, "\n")
print("Accuracy Score of our Gradient bosting Classifier is: ", accuracy_gb, "\n")
print("Accuracy Score of our Naive Baias Classifier is: ", accuracy_nb, "\n")
print("Accuracy Score of our LSTM Classifier is: ", accuracy_lstm, "\n")
print("Accuracy Score of our CNN Classifier is: ", accuracy_cnn, "\n")
print("Accuracy Score of our RNN Classifier is: ", accuracy_rnn, "\n")
# Out:
# THE ACCURACY SCORES OF OUR MODELS ARE AS FOLLOWS:
#
# Accuracy Score of our Logistic Regression Classifier is:  0.9790957705396208
#
# Accuracy Score of our Decision Tree Classifier is:  0.9965969859017987
#
# Accuracy Score of our Random Forest Classifier is:  0.9970831307729704
#
# Accuracy Score of our Gradient bosting Classifier is:  0.9970831307729704
#
# Accuracy Score of our Naive Baias Classifier is:  0.8891589693728731
#
# Accuracy Score of our LSTM Classifier is:  0.9980554205153136
#
# Accuracy Score of our CNN Classifier is:  0.997569275644142
#
# Accuracy Score of our RNN Classifier is:  0.997569275644142

# %%
# COMPARING THE ACCURACIES OF MODELS USING A BAR PLOT

plt.bar(x = ["LR","DT", "RF", "GB","NB", "LSTM","CNN","RNN"], height = [(accuracy_lr)*100, (accuracy_dt)*100,(accuracy_rf)*100,(accuracy_gb)*100,(accuracy_nb)*100,(accuracy_lstm)*100,(accuracy_cnn)*100,(accuracy_rnn)*100], color = ["red", "green", "blue", "Black", "orange","purple","yellow","Teal"])
plt.title("ACCURACIES OF OUR MODELS")
plt.ylabel("Accuracy Percentage")
plt.xlabel("Classfiers")
plt.figure(figsize=(100,100))

# %%
# CHECKING Binary Cross-Entropy Loss OF MODELS

print("THE Binary Cross-Entropy Loss OF OUR MODELS:", "\n")
print("Loss of our Logistic Regression model is: ", log_loss(y_pred_lr, y_test), "\n")
print("Loss of our Decision Tree Classifier is: ", log_loss(y_pred_dt, y_test), "\n")
print("Loss of our Random Forest Classifier is: ", log_loss(y_pred_rf, y_test), "\n")
print("Loss of our gradient boost Classifier is: ", log_loss(y_pred_gb, y_test), "\n")
print("Loss of our NaiveBayes Classifier is: ", log_loss(y_pred_nb, y_test), "\n")
print("Loss of our LSTM Classifier is: ",log_loss(y_pred_lstm,y_test), "\n")
print("Loss of our CNN Classifier is: ", log_loss(y_pred_cnn, y_test), "\n")
print("Loss of our RNN Classifier is: ", log_loss(y_pred_rnn, y_test), "\n")
# Out:
# THE Binary Cross-Entropy Loss OF OUR MODELS:
#
# Loss of our Logistic Regression model is:  0.7534648010364794
#
# Loss of our Decision Tree Classifier is:  0.12265706063384567
#
# Loss of our Random Forest Classifier is:  0.10513462340043918
#
# Loss of our gradient boost Classifier is:  0.10513462340043918
#
# Loss of our NaiveBayes Classifier is:  3.99511568921668
#
# Loss of our LSTM Classifier is:  0.07008974893362618
#
# Loss of our CNN Classifier is:  0.08761218616703267
#
# Loss of our RNN Classifier is:  0.08761218616703267

# %%
# CHECKING THE F1 SCORES OF MODELS

print("THE F1 SCORES OF OUR MODELS:", "\n")
print("F1 Score of our Logistic Regression model is: ", f1_score(y_pred_lr, y_test), "\n")
print("F1 Score of our Decision Tree Classifier is: ", f1_score(y_pred_dt, y_test), "\n")
print("F1 Score of our Random Forest Classifier is: ", f1_score(y_pred_rf, y_test), "\n")
print("F1 Score of our gradient boost Classifier is: ", f1_score(y_pred_gb, y_test), "\n")
print("F1 Score of our NaiveBayes Classifier is: ", f1_score(y_pred_nb, y_test), "\n")
print("F1 Score of our LSTM Classifier is: ", f1_score(y_pred_lstm,y_test), "\n")
print("F1 Score of our CNN Classifier is: ", f1_score(y_pred_cnn, y_test), "\n")
print("F1 Score of our RNN Classifier is: ", f1_score(y_pred_rnn, y_test), "\n")
# Out:
# THE F1 SCORES OF OUR MODELS:
#
# F1 Score of our Logistic Regression model is:  0.949941792782305
#
# F1 Score of our Decision Tree Classifier is:  0.9922135706340378
#
# F1 Score of our Random Forest Classifier is:  0.9933035714285714
#
# F1 Score of our gradient boost Classifier is:  0.9933333333333333
#
# F1 Score of our NaiveBayes Classifier is:  0.6617210682492581
#
# F1 Score of our LSTM Classifier is:  0.9955456570155902
#
# F1 Score of our CNN Classifier is:  0.9944258639910815
#
# F1 Score of our RNN Classifier is:  0.9944382647385984

# %%
# CHECKING THE RECALL SCORE

print("THE RECALL SCORES OF OUR MODELS", "\n")
print("Recall Score of our Logistic Regression model is: ", recall_score(y_pred_lr, y_test), "\n")
print("Recall Score of our Decision Tree Classifier is: ", recall_score(y_pred_dt, y_test), "\n")
print("Recall Score of our Random Forest Classifier is: ", recall_score(y_pred_rf, y_test), "\n")
print("Recall Score of our gradient boost Classifier is: ", recall_score(y_pred_gb, y_test), "\n")
print("Recall Score of our NaiveBayes Classifier is: ", recall_score(y_pred_nb, y_test), "\n")
print("Recall Score of our LSTM Classifier is: ", recall_score(y_pred_lstm,y_test), "\n")
print("Recall Score of our CNN Classifier is: ", recall_score(y_pred_cnn, y_test), "\n")
print("Recall Score of our RNN Classifier is: ", recall_score(y_pred_rnn, y_test), "\n")
# Out:
# THE RECALL SCORES OF OUR MODELS
#
# Recall Score of our Logistic Regression model is:  1.0
#
# Recall Score of our Decision Tree Classifier is:  0.9955357142857143
#
# Recall Score of our Random Forest Classifier is:  1.0
#
# Recall Score of our gradient boost Classifier is:  0.9955456570155902
#
# Recall Score of our NaiveBayes Classifier is:  1.0
#
# Recall Score of our LSTM Classifier is:  1.0
#
# Recall Score of our CNN Classifier is:  1.0
#
# Recall Score of our RNN Classifier is:  0.9977678571428571

# %%
# CHECKING THE PRECISION score
from sklearn.metrics import precision_score

print("THE PRECISION SCORES OF OUR MODELS", "\n")
print("PRECISION Score of our Logistic Regression model is: ", precision_score(y_pred_lr, y_test), "\n")
print("PRECISION Score of our Decision Tree Classifier is: ", precision_score(y_pred_dt, y_test), "\n")
print("PRECISION Score of our Random Forest Classifier is: ", precision_score(y_pred_rf, y_test), "\n")
print("PRECISION Score of our gradient boost Classifier is: ", precision_score(y_pred_gb, y_test), "\n")
print("PRECISION Score of our NaiveBayes Classifier is: ", precision_score(y_pred_nb, y_test), "\n")
print("PRECISION Score of our LSTM Classifier is: ", precision_score(y_test,y_pred_lstm) ,"\n")
print("PRECISION Score of our CNN Classifier is: ", precision_score(y_pred_cnn, y_test), "\n")
print("PRECISION Score of our RNN Classifier is: ", precision_score(y_pred_rnn, y_test), "\n")
# Out:
# THE PRECISION SCORES OF OUR MODELS
#
# PRECISION Score of our Logistic Regression model is:  0.9046563192904656
#
# PRECISION Score of our Decision Tree Classifier is:  0.9889135254988913
#
# PRECISION Score of our Random Forest Classifier is:  0.9866962305986696
#
# PRECISION Score of our gradient boost Classifier is:  0.991130820399113
#
# PRECISION Score of our NaiveBayes Classifier is:  0.49445676274944567
#
# PRECISION Score of our LSTM Classifier is:  1.0
#
# PRECISION Score of our CNN Classifier is:  0.9889135254988913
#
# PRECISION Score of our RNN Classifier is:  0.991130820399113

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
mae_lr = mean_absolute_error(y_pred_lr, y_test)
mae_dt = mean_absolute_error(y_pred_dt, y_test)
mae_rf = mean_absolute_error(y_pred_rf, y_test)
mae_gb = mean_absolute_error(y_pred_gb, y_test)
mae_mnb = mean_absolute_error(y_pred_nb, y_test)
mae_lstm = mean_absolute_error(y_pred_lstm, y_test)
mae_cnn = mean_absolute_error(y_pred_cnn, y_test)
mae_rnn = mean_absolute_error(y_pred_rnn, y_test)

# %%
print("MEAN ABSOLUTE ERROR OF OUR MODELS", "\n")
print("MEAN ABSOLUTE ERROR of our Logistic Regression model is: ", mae_lr, "\n")
print("MEAN ABSOLUTE ERROR of our Decision Tree Classifier is: ", mae_dt, "\n")
print("MEAN ABSOLUTE ERROR of our Random Forest Classifier is: ", mae_rf, "\n")
print("MEAN ABSOLUTE ERROR of our gradient boost Classifier is: ", mae_gb, "\n")
print("MEAN ABSOLUTE ERROR of our NaiveBayes Classifier is: ", mae_mnb, "\n")
print("MEAN ABSOLUTE ERROR Score of our LSTM Classifier is: ", mae_lstm ,"\n")
print("MEAN ABSOLUTE ERROR of our CNN Classifier is: ", mae_cnn, "\n")
print("MEAN ABSOLUTE ERROR of our RNN Classifier is: ", mae_rnn, "\n")
# Out:
# MEAN ABSOLUTE ERROR OF OUR MODELS
#
# MEAN ABSOLUTE ERROR of our Logistic Regression model is:  0.020904229460379193
#
# MEAN ABSOLUTE ERROR of our Decision Tree Classifier is:  0.003403014098201264
#
# MEAN ABSOLUTE ERROR of our Random Forest Classifier is:  0.002916869227029655
#
# MEAN ABSOLUTE ERROR of our gradient boost Classifier is:  0.002916869227029655
#
# MEAN ABSOLUTE ERROR of our NaiveBayes Classifier is:  0.11084103062712689
#
# MEAN ABSOLUTE ERROR Score of our LSTM Classifier is:  0.0019445794846864365
#
# MEAN ABSOLUTE ERROR of our CNN Classifier is:  0.0024307243558580457
#
# MEAN ABSOLUTE ERROR of our RNN Classifier is:  0.0024307243558580457

# %%
mse_lr = mean_squared_error(y_pred_lr, y_test)
mse_dt = mean_squared_error(y_pred_dt, y_test)
mse_rf = mean_squared_error(y_pred_rf, y_test)
mse_gb = mean_squared_error(y_pred_gb, y_test)
mse_mnb = mean_squared_error(y_pred_nb, y_test)
mse_lstm = mean_squared_error(y_pred_lstm, y_test)
mse_cnn = mean_squared_error(y_pred_cnn, y_test)
mse_rnn = mean_squared_error(y_pred_rnn, y_test)

# %%
print("MEAN SQUARE ERROR OF OUR MODELS", "\n")
print("MEAN SQUARE ERROR of our Logistic Regression model is: ", mse_lr, "\n")
print("MEAN SQUARE ERROR of our Decision Tree Classifier is: ", mse_dt, "\n")
print("MEAN SQUARE ERROR of our Random Forest Classifier is: ", mse_rf, "\n")
print("MEAN SQUARE ERROR of our gradient boost Classifier is: ", mse_gb, "\n")
print("MEAN SQUARE ERROR of our NaiveBayes Classifier is: ", mse_mnb, "\n")
print("MEAN SQUARE ERROR Score of our LSTM Classifier is: ", mse_lstm ,"\n")
print("MEAN SQUARE ERROR of our CNN Classifier is: ", mse_cnn, "\n")
print("MEAN SQUARE ERROR of our RNN Classifier is: ", mse_rnn, "\n")
# Out:
# MEAN SQUARE ERROR OF OUR MODELS
#
# MEAN SQUARE ERROR of our Logistic Regression model is:  0.020904229460379193
#
# MEAN SQUARE ERROR of our Decision Tree Classifier is:  0.003403014098201264
#
# MEAN SQUARE ERROR of our Random Forest Classifier is:  0.002916869227029655
#
# MEAN SQUARE ERROR of our gradient boost Classifier is:  0.002916869227029655
#
# MEAN SQUARE ERROR of our NaiveBayes Classifier is:  0.11084103062712689
#
# MEAN SQUARE ERROR Score of our LSTM Classifier is:  0.0019445794846864365
#
# MEAN SQUARE ERROR of our CNN Classifier is:  0.0024307243558580457
#
# MEAN SQUARE ERROR of our RNN Classifier is:  0.0024307243558580457

# %%
rmse_lr = np.sqrt(mse_lr)
rmse_dt = np.sqrt(mse_dt)
rmse_rf = np.sqrt(mse_rf)
rmse_gb = np.sqrt(mae_gb)
rmse_mnb = np.sqrt(mse_mnb)
rmse_lstm = np.sqrt(mse_lstm)
rmse_cnn = np.sqrt(mse_cnn)
rmse_rnn = np.sqrt(mse_rnn)

# %%
print("ROOT MEAN SQUARE ERROR OF OUR MODELS", "\n")
print("ROOT MEAN SQUARE ERROR of our Logistic Regression model is: ", rmse_lr, "\n")
print("ROOT MEAN SQUARE ERROR of our Decision Tree Classifier is: ", rmse_dt, "\n")
print("ROOT MEAN SQUARE ERROR of our Random Forest Classifier is: ", rmse_rf, "\n")
print("ROOT MEAN SQUARE ERROR of our gradient boost Classifier is: ", rmse_gb, "\n")
print("ROOT MEAN SQUARE ERROR of our NaiveBayes Classifier is: ", rmse_mnb, "\n")
print("ROOT MEAN SQUARE ERROR Score of our LSTM Classifier is: ", rmse_lstm ,"\n")
print("ROOT MEAN SQUARE ERROR of our CNN Classifier is: ", rmse_cnn, "\n")
print("ROOT MEAN SQUARE ERROR of our RNN Classifier is: ", rmse_rnn, "\n")
# Out:
# ROOT MEAN SQUARE ERROR OF OUR MODELS
#
# ROOT MEAN SQUARE ERROR of our Logistic Regression model is:  0.14458295010262862
#
# ROOT MEAN SQUARE ERROR of our Decision Tree Classifier is:  0.05833535890179527
#
# ROOT MEAN SQUARE ERROR of our Random Forest Classifier is:  0.05400804779872769
#
# ROOT MEAN SQUARE ERROR of our gradient boost Classifier is:  0.05400804779872769
#
# ROOT MEAN SQUARE ERROR of our NaiveBayes Classifier is:  0.3329279661234948
#
# ROOT MEAN SQUARE ERROR Score of our LSTM Classifier is:  0.04409738637024236
#
# ROOT MEAN SQUARE ERROR of our CNN Classifier is:  0.04930237677696731
#
# ROOT MEAN SQUARE ERROR of our RNN Classifier is:  0.04930237677696731
